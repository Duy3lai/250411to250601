# %%
import pandas as pd

#Load CSV
df = pd.read_csv()
# Out:
#    Delivery year  Total purchased Purchased from U.S. producers  \
# 0           2002            10.36                         13.03
# 1           2003            10.81                         14.17
# 2           2004            12.61                           - -
# 3           2005            14.36                             W
# 4           2006            18.61                           - -
#
#   Purchased from U.S. brokers and traders  \
# 0                                   10.21
# 1                                   11.05
# 2                                   12.08
# 3                                   13.76
# 4                                   20.49
#
#   Purchased from other owners and operators of U.S. civilian nuclear power reactors, other U.S. suppliers, (and U.S. government for 2007)  \
# 0                                                  W
# 1                                              10.16
# 2                                              11.30
# ...
